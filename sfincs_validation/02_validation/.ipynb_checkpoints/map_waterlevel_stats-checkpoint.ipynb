# %%
import os
import hydromt
from hydromt import DataCatalog
from hydromt_sfincs import SfincsModel, utils
import geopandas as gpd
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.colors import LinearSegmentedColormap
from datetime import datetime, timedelta
from mpl_toolkits.axes_grid1 import make_axes_locatable
import cartopy.crs as ccrs

# %%
# Load in model and read results
cat_dir = r'Z:\Data-Expansion\users\lelise\data'
yml_base_CONUS = os.path.join(cat_dir, 'data_catalog_BASE_CONUS.yml')
yml_base_Carolinas = os.path.join(cat_dir, 'data_catalog_BASE_Carolinas.yml')
yml_sfincs_Carolinas = os.path.join(cat_dir, 'data_catalog_SFINCS_Carolinas.yml')

os.chdir(r'Z:\Data-Expansion\users\lelise\projects\Carolinas_SFINCS\Chapter1_FlorenceValidation\sfincs_models\mod_v4_flor')
model_root = 'ENC_200m_sbg5m_avgN_adv1_eff75'

# Plotting the data on a map with contextual layers
mod = SfincsModel(root=model_root, mode='r', data_libs=[yml_base_CONUS, yml_base_Carolinas, yml_sfincs_Carolinas])
cat = mod.data_catalog

# %%
# Load geospatial layers for plotting
l_gdf = cat.get_geodataframe(
    r'Z:\Data-Expansion\users\lelise\data\geospatial\hydrography\nhd\NHD_H_North_Carolina_State_Shape\Shape\WBDHU6.shp')
l_gdf = l_gdf[l_gdf['Name'].isin(['Pamlico', 'Neuse', 'Onslow Bay', 'Cape Fear', 'Lower Pee Dee'])]
l_gdf.to_crs(epsg=32617, inplace=True)
l_gdf.set_index('Name', inplace=True)
basins = l_gdf

l_gdf = cat.get_geodataframe('carolinas_coastal_wb')
l_gdf.to_crs(epsg=32617, inplace=True)
coastal_wb = l_gdf.clip(basins)

l_gdf = cat.get_geodataframe('carolinas_major_rivers')
l_gdf.to_crs(epsg=32617, inplace=True)
major_rivers = l_gdf.clip(basins)

l_gdf = cat.get_geodataframe(r'Z:\Data-Expansion\users\lelise\projects\Carolinas_SFINCS\Chapter1_FlorenceValidation\hecras_bathy\RAS_point_interpolated\NHDArea_LowerPeeDee.shp')
l_gdf.to_crs(epsg=32617, inplace=True)
lpd_riv = l_gdf.clip(basins)

# %%
out_dir = os.path.join(os.getcwd(), model_root, 'validation')
gage_stats = pd.read_csv(os.path.join(out_dir, 'waterlevel', 'hydrograph_stats_by_gageID.csv'))
gage_stats = gpd.GeoDataFrame(gage_stats,
                              geometry=gpd.points_from_xy(x=gage_stats['x'], y=gage_stats['y'], crs=mod.crs))

hwm_locs = pd.read_csv(os.path.join(out_dir, 'hwm', 'hwm_error_all.csv'))
hwm_locs = gpd.GeoDataFrame(hwm_locs,
                            geometry=gpd.points_from_xy(x=hwm_locs['xcoords'], y=hwm_locs['ycoords'], crs=mod.crs))

# %%
from matplotlib.colors import BoundaryNorm

# MAP THE STATS
da = mod.grid['dep']
wkt = da.raster.crs.to_wkt()
utm_zone = da.raster.crs.to_wkt().split("UTM zone ")[1][:3]
utm = ccrs.UTM(int(utm_zone[:2]), "S" in utm_zone)
extent = np.array(basins.buffer(1000).total_bounds)[[0, 2, 1, 3]]

font = {'family': 'Arial', 'size': 10}
mpl.rc('font', **font)
mpl.rcParams.update({'axes.titlesize': 10})

col = ['bias', 'rmse', 'r2', 'pe']
label = ['(a) Bias [m]', '(b) RMSE [m]', '(c) Coef. of Determination', '(d) Peak Error [m]']


fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(6.75, 4.75), subplot_kw={'projection': utm}, tight_layout=True)
axs = axs.flatten()
for i in range(len(axs)):
    # Plot background/geography layers
    basins.plot(ax=axs[i], color='lightgrey', edgecolor='none', linewidth=1, linestyle='-', zorder=0, alpha=1)
    mod.region.plot(ax=axs[i], color='white', edgecolor='none', linewidth=0, linestyle='-', zorder=2, alpha=1)
    coastal_wb.plot(ax=axs[i], color='steelblue', edgecolor='none', linewidth=0, linestyle='-', zorder=2, alpha=0.25)
    major_rivers.plot(ax=axs[i], color='steelblue', edgecolor='none', linewidth=0.5, linestyle='-', zorder=2, alpha=1)
    lpd_riv.plot(ax=axs[i], color='steelblue', edgecolor='steelblue', linewidth=0.5, linestyle='-', zorder=2, alpha=1)
    basins.plot(ax=axs[i], color='none', edgecolor='black', linewidth=0.75, linestyle='-', zorder=3, alpha=1)


    # Add title and save figure
    axs[i].set_extent(extent, crs=utm)
    axs[i].set_title(label[i], loc='center', fontsize=9)

    if i == 0:
        axs[i].set_ylabel(f"y coord UTM zone {utm_zone} (m)", fontsize=8)
        axs[i].yaxis.set_visible(True)
        axs[i].xaxis.set_visible(False)
    elif i == 1:
        axs[i].yaxis.set_visible(False)
        axs[i].xaxis.set_visible(False)
    elif i == 2:
        axs[i].set_ylabel(f"y coord UTM zone {utm_zone} (m)", fontsize=8)
        axs[i].yaxis.set_visible(True)
        axs[i].set_xlabel(f"x coord UTM zone {utm_zone} (m)", fontsize=8)
        axs[i].xaxis.set_visible(True)
    elif i == 3:
        axs[i].yaxis.set_visible(False)
        axs[i].set_xlabel(f"x coord UTM zone {utm_zone} (m)", fontsize=8)
        axs[i].xaxis.set_visible(True)
    
    axs[i].ticklabel_format(style='sci', useOffset=False)
    axs[i].set_aspect('equal')
    axs[i].xaxis.set_tick_params(labelsize=8)
    axs[i].yaxis.set_tick_params(labelsize=8)
    
# Bias
ax=axs[0]
ranges = [-1, -0.5,-0.25, 0, 0.25, 0.5, 1]
cmap = plt.cm.get_cmap('bwr')
norm = BoundaryNorm(ranges, cmap.N)
cs = gage_stats.plot(column='bias', legend=False, cmap=cmap, norm=norm,
                ax=ax, markersize=20, edgecolor='black', linewidth=0.75, zorder=3)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
fig.colorbar(sm, ax=ax, shrink=0.7, label='', extend='both')
                           
# RMSE
ax=axs[1]
ranges = [0, 0.5, 1, 1.5, 2, 2.5]
cmap = plt.cm.get_cmap('Reds')
norm = BoundaryNorm(ranges, cmap.N)
csb = gage_stats.plot(column='rmse', legend=False, cmap=cmap, norm=norm,
                ax=ax, markersize=20, edgecolor='black', linewidth=0.75, zorder=3)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
fig.colorbar(sm, ax=ax, shrink=0.7, label='', extend='max')

# Coef of Det
ax=axs[2]
ranges = [0, 0.25, 0.5, 0.75, 1]
cmap = plt.cm.get_cmap('Reds_r')
norm = BoundaryNorm(ranges, cmap.N)
csc = gage_stats.plot(column='r2', legend=False, cmap=cmap, norm=norm,
                ax=ax, markersize=20, edgecolor='black', linewidth=0.75, zorder=3)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
fig.colorbar(sm, ax=ax, shrink=0.7, label='')

# Peak Error
ax=axs[3]
ranges = [-1, -0.5,-0.25, 0, 0.25, 0.5, 1]
cmap = plt.cm.get_cmap('bwr')
norm = BoundaryNorm(ranges, cmap.N)
gage_stats.plot(column='pe', cmap=cmap, norm=norm, legend=False, ax=ax,
                markersize=14, edgecolor='black', linewidth=0.25, alpha=1, zorder=3)
csd = hwm_locs.plot(column='error', legend=False, cmap=cmap, norm=norm, ax=ax,
              markersize=14, marker='v', edgecolor='black', linewidth=0.25, alpha=1, zorder=3)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
fig.colorbar(sm, ax=ax, label='', shrink=0.7, extend='both')

plt.tight_layout()
#plt.subplots_adjust(wspace=0.07, hspace=0.07)
plt.margins(x=0, y=0)
plt.savefig(r'Z:\Data-Expansion\users\lelise\projects\Carolinas_SFINCS\Chapter1_FlorenceValidation\map_waterlevel_stats.jpg', bbox_inches='tight', dpi=300)
#plt.close()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6.5, 4), subplot_kw={'projection': utm}, tight_layout=True)

# Plot background/geography layers
basins.plot(ax=ax, color='lightgrey', edgecolor='none', linewidth=1, linestyle='-', zorder=0, alpha=1)
mod.region.plot(ax=ax, color='white', edgecolor='none', linewidth=0, linestyle='-', zorder=2, alpha=1)
coastal_wb.plot(ax=ax, color='steelblue', edgecolor='none', linewidth=0, linestyle='-', zorder=2, alpha=0.25)
major_rivers.plot(ax=ax, color='steelblue', edgecolor='none', linewidth=0.5, linestyle='-', zorder=2, alpha=1)
lpd_riv.plot(ax=ax, color='steelblue', edgecolor='steelblue', linewidth=0.5, linestyle='-', zorder=2, alpha=1)
basins.plot(ax=ax, color='none', edgecolor='black', linewidth=1, linestyle='-', zorder=3, alpha=1)


# Peak Error
ranges = [-1, -0.5,-0.25, 0, 0.25, 0.5, 1]
cmap = plt.cm.get_cmap('bwr')
norm = BoundaryNorm(ranges, cmap.N)
gage_stats.plot(column='pe', cmap=cmap, norm=norm, legend=False, ax=ax,
                markersize=45, edgecolor='black', linewidth=0.75, alpha=0.8, zorder=3)
csd = hwm_locs.plot(column='error', legend=False, cmap=cmap, norm=norm, ax=ax,
              markersize=35, marker='v', edgecolor='black', linewidth=0.75, alpha=0.8, zorder=3)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
fig.colorbar(sm, ax=ax, label='m', extend='both')

    # Add title and save figure
ax.set_extent(extent, crs=utm)
ax.set_ylabel(f"y coord UTM zone {utm_zone} (m)", fontsize=10)
ax.set_xlabel(f"x coord UTM zone {utm_zone} (m)", fontsize=10)
ax.yaxis.set_visible(True)
ax.xaxis.set_visible(True)
ax.ticklabel_format(style='sci', useOffset=False)

plt.tight_layout()
plt.subplots_adjust(wspace=0, hspace=0)
plt.margins(x=0, y=0)
plt.savefig(r'Z:\Data-Expansion\users\lelise\projects\Carolinas_SFINCS\Chapter1_FlorenceValidation\map_peak_error.jpg', bbox_inches='tight', dpi=300)
